# %%
import pandas as pd
import numpy as np
import string

# %%
df = pd.read_excel('Prilozhenie.xlsx', 'DIM_ORG_LBY_AR')
df
# Out:
#      LBY_AR_ID               AR_CODE  LBY_AR_TP DIM_EFF_DT  \
# 0      3300889         GW83190116003          1 2016-03-21
# 1     22339612         GO14250918005          1 2018-09-25
# 2      8573073  40702810502310000202          3 2018-02-23
# 3     17104598         GO14280917010          1 2018-10-24
# 4     23416519         GO14010318011          1 2018-03-01
# ..         ...                   ...        ...        ...
# 670    8573073  40702810502310000202          3 2018-01-26
# 671    8170751  40702810902318000202          3 2018-03-01
# 672   21914657         GO14070218004          1 2018-02-07
# 673   24618427         GO14190318016          1 2018-03-19
# 674   22124435         GO24210518010          1 2018-07-25
#
#               DIM_END_DT     EFF_DT               END_DT   CST_ID  PD_ID
# 0    2999-12-31 00:00:00 2016-01-19  2016-03-21 00:00:00  1414570     43
# 1    2018-09-25 00:00:00 2018-09-25  2999-12-31 00:00:00  3508016     21
# ...

# %%
str1 = "INSERT DIM_ORG_LBY_AR(LBY_AR_ID, AR_CODE, LBY_AR_TP, DIM_EFF_DT, DIM_END_DT, EFF_DT, END_DT, CST_ID, PD_ID)\nVALUES\n"
with open('fill_table_DIM_ORG_LBY_AR1.sql', 'a', encoding="utf-8") as filehandle:
        filehandle.write('%s\n' % str1)
for i in range (400):
    str1 = "("+ str(df.iloc[i].LBY_AR_ID) + ", '" + df.iloc[i].AR_CODE + "', " + str(df.iloc[i].LBY_AR_TP) + ", '" + str(df.iloc[i].DIM_EFF_DT) + "', '"  + str(df.iloc[i].DIM_END_DT) + "', '" + str(df.iloc[i].EFF_DT) + "', '"  + str(df.iloc[i].END_DT) + "', " + str(df.iloc[i].CST_ID) + ", " + str(df.iloc[i].PD_ID) + ")"
    if i==399:
        str1 = str1 + ";"
    else:
        str1 = str1 + ","
    with open('fill_table_DIM_ORG_LBY_AR1.sql', 'a', encoding="utf-8") as filehandle:
        filehandle.write('%s\n' % str1)

# %%
str1 = "INSERT DIM_ORG_LBY_AR(LBY_AR_ID, AR_CODE, LBY_AR_TP, DIM_EFF_DT, DIM_END_DT, EFF_DT, END_DT, CST_ID, PD_ID)\nVALUES\n"
with open('fill_table_DIM_ORG_LBY_AR2.sql', 'a', encoding="utf-8") as filehandle:
        filehandle.write('%s\n' % str1)
for i in range (400, 675):
    str1 = "("+ str(df.iloc[i].LBY_AR_ID) + ", '" + df.iloc[i].AR_CODE + "', " + str(df.iloc[i].LBY_AR_TP) + ", '" + str(df.iloc[i].DIM_EFF_DT) + "', '"  + str(df.iloc[i].DIM_END_DT) + "', '" + str(df.iloc[i].EFF_DT) + "', '"  + str(df.iloc[i].END_DT) + "', " + str(df.iloc[i].CST_ID) + ", " + str(df.iloc[i].PD_ID) + ")"
    if i==674:
        str1 = str1 + ";"
    else:
        str1 = str1 + ","
    with open('fill_table_DIM_ORG_LBY_AR2.sql', 'a', encoding="utf-8") as filehandle:
        filehandle.write('%s\n' % str1)
